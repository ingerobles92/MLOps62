# %%
#import de librerias para EDA
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# **1. Visualización del dataset**

# %%
absenteeism_df = pd.read_csv('data/work_absenteeism_modified.csv')
absenteeism_df
# Out:
#          ID Reason for absence Month of absence Day of the week Seasons  \
# 0     11.0                26.0              7.0             3.0    1.0
# 1      36.0                0.0              7.0             3.0     1.0
# 2       3.0               23.0              7.0             4.0     1.0
# 3       7.0                7.0              7.0             5.0     1.0
# 4      11.0               23.0              7.0            65.0     1.0
# ..      ...                ...              ...             ...     ...
# 749    22.0               23.0             2.0              3.0     2.0
# 750    5.0                26.0             12.0             6.0     4.0
# 751     3.0               23.0             10.0             3.0    4.0
# 752    35.0                0.0              0.0             6.0     3.0
# 753     3.0               27.0              2.0            4.0      2.0
#
#     Transportation expense Distance from Residence to Work Service time  \
# 0                    289.0                            36.0        13.0
# 1                    118.0                            13.0         18.0
# 2                    179.0                            51.0         18.0
# 3                    279.0                             5.0         14.0
# 4                    289.0                            36.0         13.0
# ..                     ...                             ...          ...
# 749                  179.0                            26.0          9.0
# 750                  235.0                            20.0         13.0
# 751                  179.0                            51.0         18.0
# 752                  179.0                            45.0         14.0
# 753                 179.0                             51.0         18.0
#
#         Age Work load Average/day  ... Education  Son  Social drinker  \
# 0      33.0               239.554  ...       1.0  2.0             1.0
# 1      50.0               239.554  ...       1.0  1.0             1.0
# 2      38.0               239.554  ...       1.0  0.0             1.0
# 3      39.0               239.554  ...       1.0  2.0             1.0
# 4      33.0               239.554  ...       1.0  2.0             1.0
# ..      ...                   ...  ...       ...  ...             ...
# 749    30.0               302.585  ...       3.0  0.0             0.0
# 750    43.0               280.549  ...       1.0  1.0             1.0
# 751   38.0                253.465  ...       1.0  0.0             1.0
# 752    53.0                 error  ...       1.0  1.0             0.0
# 753    38.0               251.818  ...       1.0  0.0             1.0
#
#     Social smoker   Pet Weight   Height  Body mass index  \
# 0             0.0   1.0   90.0    172.0             30.0
# 1             0.0   0.0   98.0    178.0             31.0
# 2             0.0   0.0   89.0    170.0            31.0
# 3             1.0   0.0   68.0    168.0             24.0
# 4             0.0   1.0   90.0    172.0             30.0
# ..            ...   ...    ...      ...              ...
# 749           0.0   0.0   56.0    171.0             19.0
# 750           0.0   0.0  106.0    167.0             38.0
# 751           0.0   0.0   89.0    170.0              NaN
# 752           0.0  90.0   77.0    175.0             25.0
# 753           0.0   0.0   89.0   170.0              31.0
#
#     Absenteeism time in hours mixed_type_col
# 0                         4.0            535
# 1                         0.0            584
# 2                         2.0            249
# 3                         4.0            538
# 4                         2.0             85
# ..                        ...            ...
# 749                       1.0            156
# 750                       8.0            917
# 751                       3.0            NaN
# 752                       0.0            293
# 753                       3.0            357
#
# [754 rows x 22 columns]

# %% [markdown]
# **1.1 Visualización de las primeras 5 observaciones**

# %%
absenteeism_df.head()
# Out:
#        ID Reason for absence Month of absence Day of the week Seasons  \
# 0   11.0                26.0              7.0             3.0    1.0
# 1    36.0                0.0              7.0             3.0     1.0
# 2     3.0               23.0              7.0             4.0     1.0
# 3     7.0                7.0              7.0             5.0     1.0
# 4    11.0               23.0              7.0            65.0     1.0
#
#   Transportation expense Distance from Residence to Work Service time   Age  \
# 0                  289.0                            36.0        13.0   33.0
# 1                  118.0                            13.0         18.0  50.0
# 2                  179.0                            51.0         18.0  38.0
# 3                  279.0                             5.0         14.0  39.0
# 4                  289.0                            36.0         13.0  33.0
#
#   Work load Average/day  ... Education  Son  Social drinker Social smoker  \
# 0               239.554  ...       1.0  2.0             1.0           0.0
# 1               239.554  ...       1.0  1.0             1.0           0.0
# 2               239.554  ...       1.0  0.0             1.0           0.0
# 3               239.554  ...       1.0  2.0             1.0           1.0
# 4               239.554  ...       1.0  2.0             1.0           0.0
#
#    Pet Weight Height  Body mass index Absenteeism time in hours mixed_type_col
# 0  1.0   90.0  172.0             30.0                       4.0            535
# 1  0.0   98.0  178.0             31.0                       0.0            584
# 2  0.0   89.0  170.0            31.0                        2.0            249
# 3  0.0   68.0  168.0             24.0                       4.0            538
# 4  1.0   90.0  172.0             30.0                       2.0             85
#
# [5 rows x 22 columns]

# %% [markdown]
# **1.2 Visualización de las últimas 5 observaciones**

# %%
absenteeism_df.tail()
# Out:
#         ID Reason for absence Month of absence Day of the week Seasons  \
# 749   22.0               23.0             2.0              3.0     2.0
# 750   5.0                26.0             12.0             6.0     4.0
# 751    3.0               23.0             10.0             3.0    4.0
# 752   35.0                0.0              0.0             6.0     3.0
# 753    3.0               27.0              2.0            4.0      2.0
#
#     Transportation expense Distance from Residence to Work Service time  \
# 749                  179.0                            26.0          9.0
# 750                  235.0                            20.0         13.0
# 751                  179.0                            51.0         18.0
# 752                  179.0                            45.0         14.0
# 753                 179.0                             51.0         18.0
#
#         Age Work load Average/day  ... Education  Son  Social drinker  \
# 749    30.0               302.585  ...       3.0  0.0             0.0
# 750    43.0               280.549  ...       1.0  1.0             1.0
# 751   38.0                253.465  ...       1.0  0.0             1.0
# 752    53.0                 error  ...       1.0  1.0             0.0
# 753    38.0               251.818  ...       1.0  0.0             1.0
#
#     Social smoker   Pet Weight   Height  Body mass index  \
# 749           0.0   0.0   56.0    171.0             19.0
# 750           0.0   0.0  106.0    167.0             38.0
# 751           0.0   0.0   89.0    170.0              NaN
# 752           0.0  90.0   77.0    175.0             25.0
# 753           0.0   0.0   89.0   170.0              31.0
#
#     Absenteeism time in hours mixed_type_col
# 749                       1.0            156
# 750                       8.0            917
# 751                       3.0            NaN
# 752                       0.0            293
# 753                       3.0            357
#
# [5 rows x 22 columns]

# %% [markdown]
# **1.3 Dimensión del dataframe**

# %%
absenteeism_df.shape
# Out:
# (754, 22)

# %% [markdown]
# **2. Análisis descriptivo (univariante)**
#
# --Objetivo: Entender y describir las caracteristicas de cada una de las variables que conforman el dataset:

# %%
absenteeism_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754 entries, 0 to 753
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               746 non-null    object
#  1   Reason for absence               748 non-null    object
#  2   Month of absence                 743 non-null    object
#  3   Day of the week                  746 non-null    object
#  4   Seasons                          750 non-null    object
#  5   Transportation expense           746 non-null    object
#  6   Distance from Residence to Work  743 non-null    object
#  7   Service time                     747 non-null    object
#  8   Age                              749 non-null    object
#  9   Work load Average/day            741 non-null    object
#  10  Hit target                       746 non-null    object
#  11  Disciplinary failure             747 non-null    object
#  12  Education                        745 non-null    float64
#  13  Son                              742 non-null    object
#  14  Social drinker                   749 non-null    object
#  15  Social smoker                    744 non-null    object
#  16  Pet                              742 non-null    object
#  17  Weight                           748 non-null    float64
#  18  Height                           749 non-null    object
#  19  Body mass index                  750 non-null    object
#  20  Absenteeism time in hours        744 non-null    object
#  21  mixed_type_col                   648 non-null    object
# dtypes: float64(2), object(20)
# memory usage: 129.7+ KB

# %% [markdown]
# En el análisis del dataframe de ausentimos observamos que existen 20 columnas de tipo Object, 2 columnas de tipo float64, así como 754 filas. Se puede observar que las 22 columnas de datos, presentan valores faltantes.

# %% [markdown]
# **2.1. Análisis de variables categoricas**
#
# --Objetivo: obtener estádisticas descriptivas categoricas:
#
# *   Medidas de frecuencia (count, freq)
# *   Medidas de diversidad (unique)
# *   Medidas de tendencia central (top)

# %%
absenteeism_df.describe(include = object).T
# Out:
#                                 count unique      top freq
# ID                                746     59      3.0  106
# Reason for absence                748     51     23.0  142
# Month of absence                  743     31      3.0   80
# Day of the week                   746     21      2.0  151
# Seasons                           750     17      4.0  191
# Transportation expense            746     49    179.0  171
# Distance from Residence to Work   743     50     26.0  122
# Service time                      747     37     18.0  142
# Age                               749     40     28.0  113
# Work load Average/day             741     71  222.196   34
# Hit target                        746     36     99.0   99
# Disciplinary failure              747     10      0.0  663
# Son                               742     19      0.0  280
# Social drinker                    749     12      1.0  408
# Social smoker                     744     10      0.0  651
# Pet                               742     21      0.0  444
# Height                            749     31    170.0  161
# Body mass index                   750     40     31.0  136
# Absenteeism time in hours         744     37      8.0  195
# mixed_type_col                    648    403      bad   81

# %% [markdown]
# Posterior al análisis del dataset se puede mencionar que la razón más frecuente por la que existen asusentimos es por consulta médica.
# El mes de marzo es donde ocurren más asentismo; el tiempo de ausentimos habitual es 8hrs, el día en el que existen más ausentismo es el día Lunes y la estación más común es primavera.
#
# Se continua explorando el dataset.

# %% [markdown]
# **2.2 Visualización de variables**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Variables numéricas
float_cols = absenteeism_df.select_dtypes(include=['float']).columns.tolist()
# Variables categóricas
object_cols = absenteeism_df.select_dtypes(include='object').columns.tolist()

# Graficar variables numéricas
fig, axes = plt.subplots(4, 3, figsize=(15, 15))
plt.subplots_adjust(hspace=0.5)
axes = axes.ravel()
for i, col in enumerate(float_cols):
    ax = axes[i]
    ax.hist(absenteeism_df[col])
    ax.set_xticks(ax.get_xticks())
    ax.tick_params(axis='x', rotation=90)
    ax.set(title=f'{col}', xlabel=None)
# Oculta los subplots extra
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)
plt.show()

# Graficar variables categóricas
fig, axes = plt.subplots(4, 3, figsize=(15, 15))
plt.subplots_adjust(hspace=0.5)
axes = axes.ravel()
for i, col in enumerate(object_cols):
    ax = axes[i]
    sns.countplot(x=absenteeism_df[col], ax=ax)
    ax.tick_params(axis='x', rotation=90)
    ax.set(title=f'{col}', xlabel=None)
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3881292936.py in <cell line: 0>()
#      28 axes = axes.ravel()
#      29 for i, col in enumerate(object_cols):
# ---> 30     ax = axes[i]
#      31     sns.countplot(x=absenteeism_df[col], ax=ax)
#      32     ax.tick_params(axis='x', rotation=90)
#
# IndexError: index 12 is out of bounds for axis 0 with size 12

# %% [markdown]
# **2.3. Categorías únicas por variable y cantidad de veces que aparecen.**
#
# --Objetivo
# - Identificar si existen valores para las variables con formatos diferentes y que representen lo mismo para poder analizar un proceso de limpieza si aplica.

# %%
categorical_cols = absenteeism_df.select_dtypes(include='object').columns

for col in categorical_cols:
    print(f"\n{'='*50}")
    print(f"COLUMNA: {col}")
    print(f"{'='*50}")
    print(absenteeism_df[col].value_counts().head(10))  # Solo top 10
# Out:
# ==================================================
# COLUMNA: ID
# ==================================================
# ID
# 3.0     106
# 28.0     74
# 34.0     53
# 20.0     41
# 22.0     41
# 11.0     36
# 36.0     35
# 15.0     35
# 24.0     30
# 14.0     27
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Reason for absence
# ==================================================
# Reason for absence
# 23.0    142
# 28.0    108
# 27.0     64
# 13.0     53
# 0.0      42
# 19.0     38
# 22.0     36
# 26.0     31
# 25.0     30
# 11.0     26
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Month of absence
# ==================================================
# Month of absence
# 3.0     80
# 2.0     70
# 10.0    68
# 7.0     65
# 11.0    59
# 5.0     59
# 6.0     55
# 8.0     52
# 9.0     51
# 4.0     47
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Day of the week
# ==================================================
# Day of the week
# 2.0      151
# 4.0      150
# 3.0      145
# 6.0      133
# 5.0      118
#  3.0       9
#  2.0       9
#  4.0       8
#  5.0       6
#  6.0       6
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Seasons
# ==================================================
# Seasons
# 4.0      191
# 2.0      183
# 3.0      173
# 1.0      160
#  2.0      10
#  4.0      10
#  1.0       7
#  3.0       7
# 963.0      1
# 986.0      1
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Transportation expense
# ==================================================
# Transportation expense
# 179.0    171
# 118.0     85
# 225.0     76
# 235.0     55
# 289.0     42
# 260.0     39
# 291.0     37
# 246.0     28
# 155.0     27
# 248.0     24
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Distance from Residence to Work
# ==================================================
# Distance from Residence to Work
# 26.0    122
# 51.0    111
# 10.0     51
# 25.0     48
# 50.0     43
# 36.0     39
# 31.0     36
# 13.0     34
# 12.0     26
# 16.0     26
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Service time
# ==================================================
# Service time
# 18.0    142
# 9.0     113
# 14.0     84
# 13.0     68
# 12.0     58
# 10.0     50
# 11.0     47
# 16.0     37
# 3.0      24
# 17.0     17
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Age
# ==================================================
# Age
# 28.0    113
# 38.0    104
# 37.0     73
# 40.0     55
# 36.0     49
# 33.0     45
# 30.0     42
# 50.0     36
# 41.0     32
# 34.0     29
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Work load Average/day
# ==================================================
# Work load Average/day
# 222.196    34
# 264.249    32
# 237.656    30
# 265.017    27
# 284.853    26
# 343.253    26
# 308.593    24
# 251.818    22
# 268.519    21
# 241.476    20
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Hit target
# ==================================================
# Hit target
# 99.0    99
# 93.0    98
# 97.0    87
# 95.0    74
# 92.0    72
# 96.0    71
# 98.0    59
# 91.0    42
# 94.0    32
# 88.0    26
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Disciplinary failure
# ==================================================
# Disciplinary failure
# 0.0        663
# 1.0         40
#  0.0        36
# error        2
# 622.0        1
# invalid      1
# 208.0        1
#  1.0         1
# 228.0        1
# 541.0        1
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Son
# ==================================================
# Son
# 0.0      280
# 1.0      209
# 2.0      138
# 4.0       35
#  1.0      20
#  0.0      17
# 3.0       13
#  2.0      12
#  4.0       7
# error      2
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Social drinker
# ==================================================
# Social drinker
# 1.0      408
# 0.0      310
#  1.0      13
#  0.0      10
# 265.0      1
# 996.0      1
#  NAN       1
# 66.0       1
# 78.0       1
# ?          1
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Social smoker
# ==================================================
# Social smoker
# 0.0        651
# 1.0         51
#  0.0        33
#  1.0         2
# invalid      2
# 699.0        1
# error        1
# ?            1
# 473.0        1
# 804.0        1
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Pet
# ==================================================
# Pet
# 0.0        444
# 1.0        130
# 2.0         88
# 4.0         30
#  0.0        14
# 8.0          8
#  2.0         6
# 5.0          5
# invalid      3
#  1.0         2
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Height
# ==================================================
# Height
# 170.0    161
# 172.0    148
# 169.0     94
# 171.0     80
# 178.0     52
# 168.0     46
# 167.0     31
# 196.0     29
# 165.0     22
# 182.0     19
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Body mass index
# ==================================================
# Body mass index
# 31.0    136
# 25.0    121
# 24.0     80
# 23.0     72
# 28.0     59
# 19.0     43
# 30.0     38
# 22.0     33
# 27.0     23
# 32.0     23
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: Absenteeism time in hours
# ==================================================
# Absenteeism time in hours
# 8.0      195
# 2.0      143
# 3.0      105
# 1.0       85
# 4.0       55
# 0.0       44
# 16.0      17
# 24.0      16
#  2.0      12
#  3.0       8
# Name: count, dtype: int64
#
# ==================================================
# COLUMNA: mixed_type_col
# ==================================================
# mixed_type_col
# bad        81
# unknown    59
# 482         4
# 599         3
# 108         3
# 954         3
# 936         3
# 38          3
# 622         3
# 490         3
# Name: count, dtype: int64

# %% [markdown]
# **2.4. Porcentaje de valores faltantes por columna.**

# %%
absenteeism_df.isna().sum()
# Out:
# ID                                   8
# Reason for absence                   6
# Month of absence                    11
# Day of the week                      8
# Seasons                              4
# Transportation expense               8
# Distance from Residence to Work     11
# Service time                         7
# Age                                  5
# Work load Average/day               13
# Hit target                           8
# Disciplinary failure                 7
# Education                            9
# Son                                 12
# Social drinker                       5
# Social smoker                       10
# Pet                                 12
# Weight                               6
# Height                               5
# Body mass index                      4
# Absenteeism time in hours           10
# mixed_type_col                     106
# dtype: int64

# %% [markdown]
# **2.5. Identificar porcentaje de valores faltantes para tomar decisiones de limpieza de datos**

# %%
def detectar_valores_invalidos(df):
    """
    Detecta valores faltantes disfrazados y posibles datos inválidos por columna.
    """
    print("Resumen de valores a limpiar:")
    for col in df.columns:
        question_marks = (df[col] == '?').sum()
        errors = (df[col] == 'error').sum()
        unknowns = (df[col] == 'unknown').sum()
        invalid = (df[col] == 'invalid').sum()
        bad = (df[col] == 'bad').sum()
        nan_strings = (df[col].astype(str).str.strip().str.lower() == 'nan').sum()

        # Solo mostrar si hay algo que limpiar
        if any([question_marks, errors, unknowns, invalid, bad, nan_strings]):
            print(f"{col}:")
            if question_marks > 0:
                print(f"  '?' : {question_marks} ({question_marks/len(df)*100:.1f}%)")
            if errors > 0:
                print(f"  'error' : {errors} ({errors/len(df)*100:.1f}%)")
            if invalid > 0:
                print(f"  'invalid' : {invalid} ({invalid/len(df)*100:.1f}%)")
            if unknowns > 0:
                print(f"  'unknown' : {unknowns} ({unknowns/len(df)*100:.1f}%)")
            if bad > 0:
                print(f"  'bad' : {bad} ({bad/len(df)*100:.1f}%)")
            if nan_strings > 0:
                print(f"  'NAN' strings : {nan_strings} ({nan_strings/len(df)*100:.1f}%)")

# Usar la función
detectar_valores_invalidos(absenteeism_df)
# Out:
# Resumen de valores a limpiar:
# ID:
#   '?' : 1 (0.1%)
#   'invalid' : 1 (0.1%)
#   'NAN' strings : 8 (1.1%)
# Reason for absence:
#   '?' : 1 (0.1%)
#   'error' : 2 (0.3%)
#   'NAN' strings : 8 (1.1%)
# Month of absence:
#   'error' : 2 (0.3%)
#   'NAN' strings : 12 (1.6%)
# Day of the week:
#   'invalid' : 1 (0.1%)
#   'NAN' strings : 9 (1.2%)
# Seasons:
#   'NAN' strings : 5 (0.7%)
# Transportation expense:
#   '?' : 2 (0.3%)
#   'invalid' : 2 (0.3%)
#   'NAN' strings : 10 (1.3%)
# Distance from Residence to Work:
#   '?' : 2 (0.3%)
#   'NAN' strings : 13 (1.7%)
# Service time:
#   '?' : 1 (0.1%)
#   'NAN' strings : 8 (1.1%)
# Age:
#   '?' : 1 (0.1%)
#   'invalid' : 1 (0.1%)
#   'NAN' strings : 5 (0.7%)
# Work load Average/day:
#   '?' : 1 (0.1%)
#   'error' : 1 (0.1%)
#   'NAN' strings : 15 (2.0%)
# Hit target:
#   '?' : 2 (0.3%)
#   'invalid' : 1 (0.1%)
#   'NAN' strings : 8 (1.1%)
# Disciplinary failure:
#   'error' : 2 (0.3%)
#   'invalid' : 1 (0.1%)
#   'NAN' strings : 7 (0.9%)
# Education:
#   'NAN' strings : 9 (1.2%)
# Son:
#   '?' : 1 (0.1%)
#   'error' : 2 (0.3%)
#   'NAN' strings : 12 (1.6%)
# Social drinker:
#   '?' : 1 (0.1%)
#   'invalid' : 1 (0.1%)
#   'NAN' strings : 6 (0.8%)
# Social smoker:
#   '?' : 1 (0.1%)
#   'error' : 1 (0.1%)
#   'invalid' : 2 (0.3%)
#   'NAN' strings : 10 (1.3%)
# Pet:
#   '?' : 1 (0.1%)
#   'error' : 2 (0.3%)
#   'invalid' : 3 (0.4%)
#   'NAN' strings : 12 (1.6%)
# Weight:
#   'NAN' strings : 6 (0.8%)
# Height:
#   '?' : 1 (0.1%)
#   'NAN' strings : 5 (0.7%)
# Body mass index:
#   '?' : 1 (0.1%)
#   'invalid' : 1 (0.1%)
#   'NAN' strings : 5 (0.7%)
# Absenteeism time in hours:
#   '?' : 1 (0.1%)
#   'error' : 2 (0.3%)
#   'invalid' : 3 (0.4%)
#   'NAN' strings : 11 (1.5%)
# mixed_type_col:
#   'unknown' : 59 (7.8%)
#   'bad' : 81 (10.7%)
#   'NAN' strings : 106 (14.1%)

# %% [markdown]
# **2.6. Identificación de valores duplicados**

# %%
absenteeism_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Según el resultado, no existen valores duplicados.

# %% [markdown]
# **2.7. Identificación outliers**

# %%
import matplotlib.pyplot as plt

# Supongamos que float_cols contiene los nombres de las columnas tipo float
float_cols = absenteeism_df.select_dtypes(include='float').columns.tolist()
n = len(float_cols)
fig, axes = plt.subplots(n, 1, figsize=(4, 3 * n))
if n == 1:
    axes = [axes]  # Para el caso de una sola variable

for col, ax in zip(float_cols, axes):
    ax.boxplot(absenteeism_df[col].dropna(), labels=[col])
    ax.set_title(f'Boxplot de {col}')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4076944859.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(absenteeism_df[col].dropna(), labels=[col])
# /tmp/ipython-input-4076944859.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(absenteeism_df[col].dropna(), labels=[col])

# %% [markdown]
# **3. Limpieza**

# %% [markdown]
# Posterior a la exploración de los datos se aplicaran las siguientes actividades de limpieza

# %% [markdown]
# **3.1 Eliminar filas con ID faltantes**
# - Sin ID válido no se puede relacionar la información.

# %%
# 1. Eliminar filas con ID faltante
absenteeism_df['ID'] = absenteeism_df['ID'].replace('?', np.nan)
absenteeism_df['ID'] = absenteeism_df['ID'].replace('invalid', np.nan)
df_clean= absenteeism_df.dropna(subset=['ID'])

# %% [markdown]
# **3.2 Se elimina columna completa: mixed_type_col por falta de información**

# %%
df_clean = df_clean.drop('mixed_type_col', axis=1)

# %% [markdown]
# **3.3 Limpieza de caracteres extraños en dataframe y se susutituyen por NAN**

# %%
# Lista de valores a limpiar
valores_invalidos = ['?', 'error', 'invalid', 'unknown', 'bad']
valores_nan_str = ['NAN', 'nan', 'NAN ', ' nan ', ' NAN']
#valores_nan_str = ['NAN']

# Limpiar todas las columnas excepto 'ID' y 'mixed_type_col'
for col in df_clean.columns:
    # Reemplazar todos los valores inválidos y strings 'NAN' por np.nan
    df_clean[col] = df_clean[col].astype(str).str.strip()
    df_clean[col] = df_clean[col].replace(valores_invalidos + valores_nan_str, np.nan)

# %% [markdown]
# **4. Imputar valores faltantes según tipo de variable**
#
# Se decició imputar valores faltantes a las siguientes columnas
#
# - Reason for absence
# - Month of absence
# - Day of the week
# - Seasons
# - Transportation expense
# - Distance from Residence to Work
# - Service time
# - Age
# - Work load Average/day
# - Hit target
# - Disciplinary failure
# - Education
# - Son
# - Social drinker
# - Social smoker
# - Pet
# - Weight
# - Height
# - Body mass index
# - Absenteeism time in hours

# %%
#Silenciar el warning (más simple)
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
# Variables Integer (usar media redondeada)
integer_cols = ['Age', 'Service time', 'Transportation expense',
                'Distance from Residence to Work', 'Height',
                'Body mass index', 'Absenteeism time in hours',
                'Reason for absence', 'Social drinker', 'Social smoker',
                'Pet','Weight','Son','Hit target','Month of absence','Day of the week',
                'Seasons','Disciplinary failure','Education']

for col in integer_cols:
    if col in df_clean.columns:
        df_clean.loc[:, col] = pd.to_numeric(df_clean[col], errors='coerce')
        mean_val = round(df_clean[col].mean())
        df_clean.loc[:, col] = df_clean[col].fillna(mean_val)

# Variables continuas (usar mediana)
continuous_cols = ['Work load Average/day']

for col in continuous_cols:
    if col in df_clean.columns:
        df_clean.loc[:, col] = pd.to_numeric(df_clean[col], errors='coerce')
        median_val = df_clean[col].median()
        df_clean.loc[:, col] = df_clean[col].fillna(median_val)

# %% [markdown]
# Se visualiza dataset y se puede percibir que ya no existen valores faltantes

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 744 entries, 0 to 753
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               744 non-null    object
#  1   Reason for absence               744 non-null    object
#  2   Month of absence                 744 non-null    object
#  3   Day of the week                  744 non-null    object
#  4   Seasons                          744 non-null    object
#  5   Transportation expense           744 non-null    object
#  6   Distance from Residence to Work  744 non-null    object
#  7   Service time                     744 non-null    object
#  8   Age                              744 non-null    object
#  9   Work load Average/day            744 non-null    object
#  10  Hit target                       744 non-null    object
#  11  Disciplinary failure             744 non-null    object
#  12  Education                        744 non-null    object
#  13  Son                              744 non-null    object
#  14  Social drinker                   744 non-null    object
#  15  Social smoker                    744 non-null    object
#  16  Pet                              744 non-null    object
#  17  Weight                           744 non-null    object
#  18  Height                           744 non-null    object
#  19  Body mass index                  744 non-null    object
#  20  Absenteeism time in hours        744 non-null    object
# dtypes: object(21)
# memory usage: 127.9+ KB

# %% [markdown]
# **5. Asignar tipo de datos**

# %%
integer_cols_type ={'Age':int, 'Service time':int, 'Transportation expense':int,
                'Distance from Residence to Work':int, 'Height':int,
                'Body mass index':int, 'Absenteeism time in hours':int,
                'Reason for absence':int, 'Social drinker':int, 'Social smoker':int,
                'Pet':int,'Weight':int,'Son':int,'Hit target':int,'Month of absence':int,'Day of the week':int,
                'Seasons':int,'Disciplinary failure':int,'Education':int}

continuous_cols_type = {'Work load Average/day':float}

df_clean = df_clean.astype(integer_cols_type)
df_clean = df_clean.astype(continuous_cols_type)

# %% [markdown]
# **6. Visualización de dataframe limpio y sin valores faltantes**

# %%
df_clean.isna().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %% [markdown]
# **6.1 Se exporta dataframe limpio a .csv**

# %%
df_clean.to_csv("/work/data/processed/absenteeism_cleaned.csv", index=False)
